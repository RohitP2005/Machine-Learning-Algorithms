# %%
# Importing Modules
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from naiveBayes import NaiveBayes
from sklearn.preprocessing import StandardScaler

# %%
#Imporing Dataset
data = pd.read_csv('./diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Splitting Train-Test
x = data.drop(columns=['Outcome'])
y = data['Outcome']
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=1234)

# %%
xtrain
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 733            2      106             56             27      165  29.0
# 394            4      158             78              0        0  32.9
# 359            1      196             76             36      249  36.5
# 566            1       99             72             30       18  38.6
# 654            1      106             70             28      135  34.2
# ..           ...      ...            ...            ...      ...   ...
# 372            0       84             64             22       66  35.8
# 204            6      103             72             32      190  37.7
# 53             8      176             90             34      300  33.7
# 294            0      161             50              0        0  21.9
# 723            5      117             86             30      105  39.1
#
#      DiabetesPedigreeFunction  Age
# 733                     0.426   22
# 394                     0.803   31
# 359                     0.875   29
# 566                     0.412   21
# 654                     0.142   22
# ..                        ...  ...
# 372                     0.545   21
# 204                     0.324   55
# 53                      0.467   58
# 294                     0.254   65
# 723                     0.251   42
#
# [614 rows x 8 columns]

# %%
scaler = StandardScaler().fit(xtrain)

# Transform both the training and testing data
X_train_scaled = scaler.transform(xtrain)
X_test_scaled = scaler.transform(xtest)

# %%
X_train_scaled
# Out:
# array([[-0.55713856, -0.47283463, -0.67075629, ..., -0.37293055,
#         -0.11247739, -0.97288519],
#        [ 0.02761883,  1.15959012,  0.45604087, ...,  0.12286087,
#          1.07627438, -0.21396882],
#        [-0.84951726,  2.35251591,  0.35360476, ...,  0.58051448,
#          1.30330389, -0.3826169 ],
#        ...,
#        [ 1.19713363,  1.72466023,  1.0706575 , ...,  0.22456167,
#          0.01680331,  2.06278028],
#        [-1.14189596,  1.25376847, -0.9780646 , ..., -1.27552519,
#         -0.65482568,  2.65304856],
#        [ 0.31999753, -0.12751401,  0.86578529, ...,  0.9110421 ,
#         -0.66428524,  0.71359563]])

# %%
#Initialize Model
nb = NaiveBayes()
#Fit the Model
nb.fit(X_train_scaled, ytrain.values)

# %%
#Make Predictions
y_pred = nb.predict(X_test_scaled)

# %%
#Check Accuracy
np.sum(ytest == y_pred) / len(ytest)
# Out:
# 0.7597402597402597
